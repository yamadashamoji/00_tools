# %% [markdown]
# <a href="https://colab.research.google.com/github/yamadashamoji/tools/blob/main/000_1%E6%97%A51%E3%82%A2%E3%83%97%E3%83%AA%EF%BD%9C100%E6%97%A5%E3%83%81%E3%83%A3%E3%83%AC%E3%83%B3%E3%82%B8%E8%A8%88%E7%94%BB%E8%A1%A8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 📅 1日1アプリ｜100日チャレンジ計画表
#
# | Day | アプリ名（概要） |
# |-----|------------------|
# | 1 | [パスワード自動生成](https://colab.research.google.com/drive/1YrZZO_mByl5k1IYairZxLiOOJ614TWBB?usp=sharing) |
# | 2 | IT用語辞典から本文テキストを抽出する |
# | 3 | テキスト文字数カウンター |
# | 4 | サイコロアプリ（1～6を表示） |
# | 5 | Webサイトから画像のみを収集するアプリ |
# | 6 | [日付計算（何日後・何日前）](https://colab.research.google.com/drive/1bsusrf5WwuEF3cyDOpeGFb1cZbSuJPPw?usp=sharing) |
# | 7 | 音楽再生スクリプト（MP3再生） |
# | 8 | CSVファイルのグラフ化ツール |
# | 9 | PDF結合＆分割 |
# | 10 | ToDoリストアプリ（テキスト入力＆保存） |
#
# | Day | アプリ名（概要） |
# |-----|------------------|
# | 11 | メモ帳（自動日付保存） |
# | 12 | 占いアプリ（今日の運勢） |
# | 13 | [QRコード生成ツール](https://colab.research.google.com/drive/1nN11IRCmZz3ksPs1xzvmZHpMmlu8fYm1?usp=sharing) |
# | 14 | 翻訳ツール（英⇔日） |
# | 15 | ポモドーロタイマー |
# | 16 | 短文小説生成ツール（プロンプト） |
# | 17 | 画像→テキスト抽出（OCR） |
# | 18 | ハッシュ化ツール（SHA256, MD5） |
# | 19 | Webページのタイトル抽出 |
# | 20 | フォルダ整理（拡張子で分類） |
#
# | Day | アプリ名（概要） |
# |-----|------------------|
# | 21 | JSONフォーマッター |
# | 22 | GitHubプロフィールビューワー |
# | 23 | 曜日カレンダー |
# | 24 | 音声ファイル→テキスト（Whisper） |
# | 25 | 音声再生速度チェンジャー |
# | 26 | フラッシュカードジェネレーター |
# | 27 | 単語帳＆暗記チェック |
# | 28 | マークダウン→HTML変換 |
# | 29 | IPアドレス情報取得 |
# | 30 | ファイルサイズ一覧表示 |
#
# | Day | アプリ名（概要） |
# |-----|------------------|
# | 31 | 単位変換（長さ・重さ・時間） |
# | 32 | ChatGPTプロンプトテンプレート支援ツール |
# | 33 | ストップウォッチ |
# | 34 | 数学公式テストアプリ |
# | 35 | 画像一括リサイズ |
# | 36 | Webスクレイピング→CSV（天気 or 為替） |
# | 37 | ログイン試行シミュレーター |
# | 38 | 重複データ検出ツール（CSV） |
# | 39 | 経過時間トラッカー |
# | 40 | 曜日→日付一覧表示 |
#
# | Day | アプリ名（概要） |
# |-----|------------------|
# | 41 | ニュース取得（News API） |
# | 42 | APIからRSS一覧抽出 |
# | 43 | 習慣トラッカー |
# | 44 | Pythonコード整形 |
# | 45 | 統計量算出ツール |
# | 46 | 翻訳付き文章要約ツール |
# | 47 | ChatBotミニアプリ |
# | 48 | テキスト要約＋キーワード抽出 |
# | 49 | 書いたコードの自動解説ツール |
# | 50 | 画像にフィルターをかけるツール |
#
# | Day | アプリ名（概要） |
# |-----|------------------|
# | 51 | タイムゾーン変換ツール |
# | 52 | 週の予定表作成（JSON→表） |
# | 53 | 音読トレーニングアプリ（TTS） |
# | 54 | コード→フローチャート生成 |
# | 55 | 天気表示アプリ（OpenWeather API） |
# | 56 | 勉強時間の可視化（棒グラフ） |
# | 57 | おみくじアプリ（複数カテゴリ） |
# | 58 | エラー日本語解説アプリ |
# | 59 | ファイル監視スクリプト |
# | 60 | PDFからテキスト抽出ツール |
#
# | Day | アプリ名（概要） |
# |-----|------------------|
# | 61 | Webリンク抽出ツール |
# | 62 | AIキャラ一言ボット |
# | 63 | 着せ替えメーカー（画像合成） |
# | 64 | タグ自動抽出ツール（テキスト分析） |
# | 65 | APIドキュメント表示ビューワー |
# | 66 | CSVデータの欠損値チェック |
# | 67 | GitコマンドGUI練習アプリ |
# | 68 | 自作ライブラリ管理ビューア |
# | 69 | ファイルのチェックサム比較 |
# | 70 | 月間スケジューラー（GUIカレンダー風） |
#
# | Day | アプリ名（概要） |
# |-----|------------------|
# | 71 | テキスト分類（ポジティブ/ネガ） |
# | 72 | 類義語提案アプリ |
# | 73 | Markdown日記ツール |
# | 74 | 自動日報作成ツール |
# | 75 | Twitter投稿収集（Twitter API） |
# | 76 | 動画のカット＆結合（moviepy） |
# | 77 | メール風ジェネレーター |
# | 78 | ストップワード除去ツール |
# | 79 | おしゃれなランディングページ模写（HTML生成） |
# | 80 | ファイル名一括変更ツール |
#
# | Day | アプリ名（概要） |
# |-----|------------------|
# | 81 | Excel比較＆差分抽出 |
# | 82 | コード断片クイズアプリ |
# | 83 | 自動タグ分類でのフォルダ分類 |
# | 84 | PDF→画像変換 |
# | 85 | 音声録音→保存 |
# | 86 | GUI付き簡易チャットアプリ |
# | 87 | 時間帯ごとの作業効率可視化 |
# | 88 | コマンド履歴ログビューア |
# | 89 | タスク依存関係マップ生成 |
# | 90 | セキュアメモアプリ（自動消去） |
#
# | Day | アプリ名（概要） |
# |-----|------------------|
# | 91 | コーディング集中用タイマー |
# | 92 | Markdown→PDF変換 |
# | 93 | 天気＆気温履歴アプリ（グラフ化） |
# | 94 | RSSまとめリーダー |
# | 95 | 毎朝の予定通知ボット（時間指定） |
# | 96 | 動画から音声抽出 |
# | 97 | AIによる自動タイトル提案ツール |
# | 98 | ファイル圧縮・解凍ツール |
# | 99 | API使用量トラッカー |
# | 100 | 100日分の成果まとめアプリ（自動振り返り）🎉 |
# | XXX | Pythonを用いて決済システムをつくる |
# | XXX | カレンダー・予定表に関するアプリをつくる |
